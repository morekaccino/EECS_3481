# %% [markdown]
# <a href="https://colab.research.google.com/github/mowhamadrexa/EECS3481Assignments/blob/main/Q9_17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# No it is not safe<br>
# Once Bob leaks her private key, an attacker can use the private key to factor the modulus, N.<br>
# If Bob doesn't change his modulus, an attacket can break every message he sends. It is important to change modulus.![image.png](data:image/png;base64,...)

# %% [markdown]
# The algorithm in the figure 9.8, iterates the binary representation of $a$ from left to right. Let's assume we're in the middle of the process of this algorithm, if c is equal to the current exponent, if the next bit is 0 -> exponent doubled by 1 binary left shift<br>
# Throughout the process, the value of $d = a c \mod n$ is preserved, until we hit the point where $c = b$.
# <br><br><br>
# The algo in the question, process the binary representation from right to left. the state of $a  n = d \cdot T^{E}$ is preserved. Since at the end $T = 0$, we left with $an = d$.
