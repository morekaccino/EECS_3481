# %% [markdown]
# <a href="https://colab.research.google.com/github/mowhamadrexa/EECS3481Assignments/blob/main/Q9_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# We are going to use this method from the textbook<br><br>
# ![image.png](data:image/png;base64,...)

# %%
from math import gcd

# %%
for i in range(2, 36):
  for j in range(2, 36):
    if i * j == 35 and gcd(i, j) == 1:
      print([i, j])
# Out:
# [5, 7]
# [7, 5]

# %%
p = 7
q = 5

# %%
n = p * q
n
# Out:
# 35

# %%
phi = (p - 1) * (q - 1)
phi
# Out:
# 24

# %%
e = 5
e
# Out:
# 5

# %%
gcd(phi, e)
# Out:
# 1

# %%
d = 0
for i in range(phi):
  if i * e % phi == 1:
    d = i
    break
d
# Out:
# 5

# %%
publicKey = [e, n]
privateKey= [d, n]
print('PU', publicKey)
print('PR', privateKey)
# Out:
# PU [5, 35]
# PR [5, 35]

# %%
# Decrption
C = 10
M = C**d % n
M
# Out:
# 5

# %% [markdown]
# M = 5
