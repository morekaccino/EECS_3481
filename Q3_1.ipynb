# %% [markdown]
# <a href="https://colab.research.google.com/github/mowhamadrexa/EECS3481Assignments/blob/main/Q3_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # (a)
# **There are no limitation** for `b`.  `b` can only shift the assignments left or right. However, `b` gives repetitive values for integers > 25 or < 0; So it is recommended to keep it in this range [0, 25];

# %% [markdown]
# # (b)
# $26 = 13 \times 2$<br>
# all the multiples of 2, $2 \times x, where \; 2\times x < 26$<br>
# combined with<br>
# all the multiples of 13, $13 \times x, where \; 13\times x < 26$<br>
# in conclusion: $x \in \begin{Bmatrix}
# 2, 4, 6, 8, 10, 12, 13, 14, 16, 18, 20, 22, 24
# \end{Bmatrix}$ are the values that CANNOT be assigned to $a$.

# %% [markdown]
# # (c)
# I just explained it in part b, but let me elaborate it.<br>
# 26 can be written as the multiplication of 2 prime numbers, 2 and 13.
# If we choose any value in the range of $a \in \begin{Bmatrix}
# 2, 4, 6, 8, 10, 12, 13, 14, 16, 18, 20, 22, 24
# \end{Bmatrix}$, what happens is that the mapping function won't be one-to-one anymore.<br>
# For instance, if we assign a = 2, and b = 1<br>
# We will see that at `p` and `q` we get the same value for different letters (which is bad).
# ![Capture.PNG](data:image/png;base64,...)
# <br>But If we choose any other value for a, like 3, **the function will still be one-to-one for integer values of x-axis**
