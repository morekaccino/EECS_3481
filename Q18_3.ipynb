# %% [markdown]
# <a href="https://colab.research.google.com/github/mowhamadrexa/EECS3481Assignments/blob/main/Q18_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # a)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # b)

# %% [markdown]
# - The shared key and init vector (IV) are sent to RC4 (they are concatinated)<br>
# - RC4 decrypts the received cipher text to extract data and ICV.<br>
# - The ICV is calculated seperately and is compared to the encrypted ICV that we received to make sure they match (authentication).

# %% [markdown]
# # c)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
