# %% [markdown]
# <a href="https://colab.research.google.com/github/mowhamadrexa/EECS3481Assignments/blob/main/Q7_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # a)

# %% [markdown]
# No.<br>
#
# The encrption variables of $P_i$ are only $Key$ and $C_{i-1}$. $P_{i}$  as output, only relies on inputs $C_{i-1}$ and $C_{i}$.
# <br>
# ![image.png](data:image/png;base64,...)
# <br>

# %% [markdown]
# # b)

# %% [markdown]
# If $P_{i}$ is corrupted, this corruption will affect $C_{i}$ as well. Since $C_{i}$ is the input of $C_{i+1}$, and $C_{i+1}$ is the input of $C_{i+2}$, and $C_{i+2}$ is the input of $C_{i+3}$, etc. All the blocks after $C_{i}$ will be under the effect of this error.<br>
# However, in the decryption process, we can restore the plaintext, except for the corrupted block.
